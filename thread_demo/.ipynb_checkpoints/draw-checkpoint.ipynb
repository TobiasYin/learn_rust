# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("count.txt") as f:
    data = [int(line.split()[1]) for line in f.readlines() if line.startswith("now")]

# %%
data = np.array(data)

# %%
l = len(data)

# %%
plt.plot(data[l//4:l//5 *3])
